# %%
import pandas as pd
csv = pd.read_csv('../msi_benchmark.csv')

# %%
# Out:
#      trustworthiness  continuity  mrre_false  mrre_missing  pearson_r  \
# 0           0.965831    0.978954    0.957105      0.974669   0.980278
# 1           0.972916    0.970933    0.969928      0.969696   0.932599
# 2           0.965546    0.972400    0.961771      0.967885   0.982457
# 3           0.964559    0.966984    0.968247      0.969575   0.751297
# 4           0.966555    0.965380    0.969937      0.967863   0.827232
# ..               ...         ...         ...           ...        ...
# 315         0.977714    0.965213    0.974183      0.970047   0.777845
# 316         0.974904    0.964747    0.974470      0.968121   0.820412
# 317         0.976120    0.975768    0.977399      0.975690   0.688705
# 318         0.957119    0.958775    0.956330      0.960510   0.656757
# 319         0.948384    0.958229    0.949237      0.960664   0.867558
#
#      spearman_rho  ca_trustworthiness  ca_continuity   ami_avg  \
# ...
